# %%
! pip install pyspark
# Out:
# Requirement already satisfied: pyspark in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (3.5.3)
# Requirement already satisfied: py4j==0.10.9.7 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from pyspark) (0.10.9.7)
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
import pyspark

# %% [markdown]
# **Let's try to read file using Pandas**

# %%
import pandas as pd
pd.read_csv('test1.csv')
# Out:
#      Name  Age
# 0   Tarif   22
# 1  Salman   37
# 2   Sayan   50

# %% [markdown]
# **1- At First Import SparkSession**

# %%
from pyspark.sql import SparkSession

# %% [markdown]
# **2- Create a Spark Session**

# %%
spark = SparkSession.builder.appName('Practise').getOrCreate()
# Out:
# 24/12/16 10:51:04 WARN Utils: Your hostname, Mds-MacBook-Air.local resolves to a loopback address: 127.0.0.1; using 192.168.1.5 instead (on interface en0)
# 24/12/16 10:51:04 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/12/16 10:51:05 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 24/12/16 10:51:16 WARN GarbageCollectionMetrics: To enable non-built-in garbage collector(s) List(G1 Concurrent GC), users should configure it(them) to spark.eventLog.gcMetrics.youngGenerationGarbageCollectors or spark.eventLog.gcMetrics.oldGenerationGarbageCollectors

# %% [markdown]
# **Reduce log level to ERROR

# %%
spark.sparkContext.setLogLevel("ERROR")

# %% [markdown]
# ![Copy of Add a subheading (1).png](attachment:3701466a-5b49-4c46-84a4-eddd22aeb558.png)

# %% [markdown]
# Check if Spark is running

# %%
print("Spark Session created successfully!")
# Out:
# Spark Session created successfully!

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://192.168.1.5:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.3</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Practise</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# Let's try to read file using Spark

# %%
df_pyspark = spark.read.csv('test1.csv')

# %%
df_pyspark.show()
# Out:
# +------+---+
# |   _c0|_c1|
# +------+---+
# |  Name|Age|
# | Tarif| 22|
# |Salman| 37|
# | Sayan| 50|
# +------+---+

# %% [markdown]
# But I want to see the first row as header

# %%
spark.read.option('header','true').csv('test1.csv').show()
# Out:
# +------+---+
# |  Name|Age|
# +------+---+
# | Tarif| 22|
# |Salman| 37|
# | Sayan| 50|
# +------+---+

# %% [markdown]
# Let's see the type & DataFrame

# %%
df_pyspark = spark.read.option('header','true').csv('test1.csv')
type(df_pyspark)
# Out:
# pyspark.sql.dataframe.DataFrame

# %% [markdown]
# Let's print Schema

# %%
df_pyspark.printSchema()
# Out:
# root
#  |-- Name: string (nullable = true)
#  |-- Age: string (nullable = true)
